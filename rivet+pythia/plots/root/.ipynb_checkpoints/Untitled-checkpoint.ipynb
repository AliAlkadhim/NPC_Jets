# %%
import ROOT
import uproot3

# %%
InputFile_post = "suppr250_bornktmin10_100M_ParsiParams_posthadron_merged.root"
InputFile_pre = "suppr250_bornktmin10_100M_ParsiParams_prehadron_merged.root"
f_post = ROOT.TFile.Open(InputFile_post, 'READ')
f_pre = ROOT.TFile.Open(InputFile_pre, 'READ')

fu = uproot3.open(InputFile)
fu["CMS_2021_I1972986"].keys()
# Out:
# [b'd21-x01-y01;1',
#  b'd01-x01-y01;1',
#  b'd03-x01-y01;1',
#  b'd04-x01-y01;1',
#  b'd24-x01-y01;1',
#  b'd02-x01-y01;1',
#  b'd22-x01-y01;1',
#  b'd23-x01-y01;1']

# %%
hist_post = f_post.Get("CMS_2021_I1972986/d01-x01-y01")
hist_pre = f_pre.Get("CMS_2021_I1972986/d01-x01-y01")

c = ROOT.TCanvas("", "", 600, 600)
c.SetLogy()

c.Draw()
hist_post.Draw("SAME")
hist_pre.Draw("SAME")

# %%
ratio_hist = hist_post.Clone("ratio_hist")
ratio_hist.SetMinimum(0.)
ratio_hist.SetMaximum(2.0)
x=ratio_hist.GetXaxis()
ratio_hist.SetAxisRange(0,800)

ratio_hist.Sumw2()
ratio_hist.Divide(hist_pre)
c = ROOT.TCanvas("", "", 600, 600)

c.Draw()
ratio_hist.Draw()
# Out:
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created

# %%
ratio_hist.SetAxisRange(0,800)
