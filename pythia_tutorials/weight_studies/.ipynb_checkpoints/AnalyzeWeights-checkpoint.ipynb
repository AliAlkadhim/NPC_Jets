# %%
import uproot
import numpy as np
import matplotlib as mp; import matplotlib.pyplot as plt; 
#reset matplotlib stle/parameters
import matplotlib as mpl
import mplhep as hep
hep.style.use("CMS")
print(uproot.__version__)
import uproot3
print(uproot3.__version__)
import uproot3 as uproot
# import uproot
import argparse
import awkward
# update fonts
FONTSIZE = 14
font = {'family' : 'serif',
        'weight' : 'normal',
        'size'   : FONTSIZE}
mp.rc('font', **font)

# set usetex = False if LaTex is not 
# available on your system or if the 
# rendering is too slow
mp.rc('text', usetex=True)

# set a seed to ensure reproducibility
seed = 128
rnd  = np.random.RandomState(seed)
# Out:
# 4.3.4
# 3.14.4

# %%
ptbins=[97,  133,  174,  220,  272,  330,  395,  468,  548,  638,  737,  846, 967, 1101, 1248, 1410, 1588, 1784, 2000, 2238, 2500, 2787]

# %% [markdown]
# ### We want to answer the question: what is a good event weight threshold?

# %%
def plt_weights(Weight_file, N):
    bins=100
    with uproot.open(Weight_file) as f:
        print('file keys', f.keys())
        tree=f['tree']
        print('tree keys', tree.keys())
        evweight_pre = tree.arrays('evtWeight', outputtype=tuple) 
        #yes doing below is comput. faster than converting the uproot to np
        w_min, w_max = np.array(evweight_pre).min(), np.array(evweight_pre).max()
        print('wmin, wmax = \t ', w_min,',\t', w_max)
        pTJet = tree.arrays('pTJet', outputtype=tuple)
        
        fig, ax = plt.subplots(1,2)
        if 'pre' in Weight_file: parton_or_hadron = 'parton'
        else: parton_or_hadron = 'hadron'
        ax[0].hist(evweight_pre, label='%s jets' % parton_or_hadron,bins=bins)
        ax[0].set_yscale('log')
        ax[0].set_title(r'CUEP8M1 $N_{events}$ = %s' % str(N))
        ax[0].set_xlabel(r'$w_{event}$')
        # ax[0].set_xlim(0,0.5)
        ax[0].legend()
        
        ax[1].hist(pTJet, label='%s jets $p_T$' % parton_or_hadron,bins=bins)
        ax[1].set_title('CUEP8M1')
        ax[1].set_xlabel(r'jet $p_T$')
        ax[1].legend()      
        
        plt.tight_layout(); plt.show()

# %%
# w_file='WEIGHTS_post_10K_ParisParams.root'
# w_file='WEIGHTS_pre_10K_ParisParams.root'
w_file='unbiased/WEIGHTS_pre_100K_ParisParams_unbiased.root'
plt_weights(w_file, N=10000)
# Out:
# file keys [b'tree;1']
# tree keys [b'numJets', b'pTJet', b'evtWeight']
# wmin, wmax = 	  1.0 ,	 1.0

# %%
def hist_ax(ax, values, label, xlabel,xrange=None, yscale=None, xscale=None, ylabel=None, ax_title=None, alpha=1, bins=16):
    ax.hist(values, label=label, alpha=alpha,bins=16); ax.legend(fontsize=15)
    ax.set_xlabel(xlabel,fontsize=25)
    if ax_title:
        ax.set_title(ax_title)
    if yscale:
        ax.set_yscale(yscale)
    if xscale:
        ax.set_xscale(xscale)
    if xrange:
        xmin, xmax = xrange
        ax.set_xlim(xmin,xmax)

def show_basic_info(values, label):
    #assuming uproot tuple values
    val_min, val_max = np.array(values).min(), np.array(values).max()
    print('\n %s_min, %s_max = \t ' % (label, label), val_min,',\t', val_max, '\n')
    shape = np.array(values).shape
    print('%s_shape = ' % label, shape) 
    
def get_centers(edges):
    return (edges[1:]+edges[:-1])/2

# %%
def log_w_log_pt(filepre, filepost, N):
    S=int(3e5)
    with uproot.open(filepre) as filepre:
        with uproot.open(filepost) as filepost:
            nrows, ncols = 1, 2
            fig, ax = plt.subplots(nrows, ncols, figsize=(30,15))
            print('file keys', filepre.keys())
            treepre = filepre["tree"]
            treepost = filepost["tree"]
            print()
            print('treepre keys',treepre.keys())
            print('treepost keys',treepost.keys())
            print()
            print('treepre["pTJet"] =',treepre["pTJet"])
        #         print()

            Axes_font=25
            ptpre = treepre.arrays(["pTJet"], outputtype = tuple)[0].flatten()[:S]           
            ptpost = treepost.arrays(["pTJet"], outputtype = tuple)[0].flatten()[:S]
            print('ptpre=', ptpre[:10])
            print('ptpost=', ptpost[:10])
            show_basic_info(ptpre, label='parton_jet_pT')

            evweight_pre = treepre.arrays('evtWeight', outputtype=tuple)[0].flatten()[:S]
            show_basic_info(evweight_pre, label='evweight_pre')
            evweight_post = treepost.arrays('evtWeight', outputtype=tuple)[0].flatten()[:S]
            show_basic_info(evweight_pre, label='parton_jet_event_weights')
            B=50
            
            R=(0,3000)
            
            X = np.log(ptpre)
            Y =np.log(evweight_pre)
            slope= (Y.min() - Y.max())/(X.max()-X.min())
            
            # slope = - 25/(8-1) 
            slope = -4.5
            y_int = 12.186 + 1.5
            print(f'slope={slope}')
            y = slope * X + y_int
            

            ax[0].scatter(X, Y, s=0.3)
            ax[0].set_ylim( Y.min(), 0.2)
            ax[0].plot(X, y, c='r' )
            ax[0].set_ylabel('$log(w_{PS})$')
            ax[0].set_xlabel('$log(p_T)$')

            # plt.yscale('log')
            ax[0].legend()
            
           
            w_mask=Y < y
            filtered_w = Y[w_mask]#we want weights below the red line
            filtered_pt = X[w_mask]
            
            print(len(filtered_w))
            ax[1].scatter(filtered_pt, filtered_w, s=0.3)
            
            

            # ax[1].hist(ptpre, bins=B, label='PS jet weighted', range=R, alpha=0.35, weights=evweight_pre)
            plt.show()

# %%
file_pre='biased/pre/WEIGHTS_pre_100K_ParisParams_biased.root'
file_post='biased/post/WEIGHTS_post_100K_ParisParams_biased.root'
log_w_log_pt(file_pre, file_post, N=100000)
# Out:
# file keys [b'tree;1']
#
# treepre keys [b'numJets', b'pTJet', b'evtWeight']
# treepost keys [b'numJets', b'pTJet', b'evtWeight']
#
# treepre["pTJet"] = <TBranch b'pTJet' at 0x7f55050b92d0>
# /home/ali/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: RuntimeWarning: divide by zero encountered in log
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ptpre= [  0.           0.         285.03810387 192.98279924 128.00686358
#   42.86144494  34.67190142  25.53549635  19.48882637  16.81313874]
# ptpost= [  0.           0.          28.87643675  26.9488977   12.71211775
#   12.71211775  12.71211775 375.07528705 372.64908738  61.90323897]
#
#  parton_jet_pT_min, parton_jet_pT_max = 	  0.0 ,	 3604.7934847998154
#
# parton_jet_pT_shape =  (300000,)
#
#  evweight_pre_min, evweight_pre_max = 	  1.8273135085853847e-11 ,	 0.998180472645993
#
# evweight_pre_shape =  (300000,)
#
#  parton_jet_event_weights_min, parton_jet_event_weights_max = 	  1.8273135085853847e-11 ,	 0.998180472645993
#
# parton_jet_event_weights_shape =  (300000,)
# slope=-4.5
# 295955

# %%
def pt_w_cut_ratio(filepre, filepost, N):
    S=int(3e5)
    with uproot.open(filepre) as filepre:
        with uproot.open(filepost) as filepost:

            print('file keys', filepre.keys())
            treepre = filepre["tree"]
            treepost = filepost["tree"]
            print()
            print('treepre keys',treepre.keys())
            print('treepost keys',treepost.keys())
            print()
            print('treepre["pTJet"] =',treepre["pTJet"])
        #         print()

            Axes_font=25
            ptpre = treepre.arrays(["pTJet"], outputtype = tuple)[0].flatten()[:S]           
            ptpost = treepost.arrays(["pTJet"], outputtype = tuple)[0].flatten()[:S]
            print('ptpre=', ptpre[:10])
            print('ptpost=', ptpost[:10])
            show_basic_info(ptpre, label='parton_jet_pT')

            evweight_pre = treepre.arrays('evtWeight', outputtype=tuple)[0].flatten()[:S]
            show_basic_info(evweight_pre, label='evweight_pre')
            evweight_post = treepost.arrays('evtWeight', outputtype=tuple)[0].flatten()[:S]
            show_basic_info(evweight_pre, label='parton_jet_event_weights')
            B=50
            
            R=(0,3000)
            
            X = np.log(ptpre)
            Y =np.log(evweight_pre)
            # slope= (Y.min() - Y.max())/(X.max()-X.min())
            
            # slope = - 25/(8-1) 
            slope = -4.5
            y_int = 12.186 + 1.5
            print(f'slope={slope}')
            y = slope * X + y_int
            
            w_mask=Y < y
            filtered_w = Y[w_mask]#we want weights below the red line
            filtered_ptpre = ptpre[w_mask]
            
            nrows, ncols = 2, 1
            fig, (ax1, ax2) = plt.subplots(nrows, ncols, figsize=(3 * 3.5 * 3 / 2.5, 3 * 3.8), gridspec_kw={"height_ratios": [2, 0.5]})
            ptpre_counts, ptpre_edges = np.histogram(ptpre, bins=B, range=R)
            ptpre_edge_centers=ptpre_edges[1:]/2 + ptpre_edges[:-1]/2
            ax1.step(ptpre_edge_centers, ptpre_counts, where='mid',label='PS jet', linewidth=4)
            # ax1.scatter(ptpre_edge_centers, ptpre_counts, label='PS jet')
            
            filtered_ptpre_counts, filtered_ptpre_edges = np.histogram(filtered_ptpre, bins=B, range=R)
            filtered_ptpre_edge_centers=filtered_ptpre_edges[1:]/2 + filtered_ptpre_edges[:-1]/2
            ax1.step(filtered_ptpre_edge_centers, filtered_ptpre_counts, where='mid',label=r'PS jet with $w$ cut', linewidth=4)
            
            # ax1.hist(ptpre, bins=B, range=R, label='PS jet', alpha=0.3)
            # ax1.hist(filtered_ptpre, bins=B, range=R, label='PS jet with w cut', alpha=0.3)

            ax1.set_yscale('log')
            ax1.legend()
            ax1.set_xlabel(r'jet $p_T$ [GeV]',fontsize=25)
            
            ax2.scatter(ptpre_edge_centers, ptpre_counts/filtered_ptpre_counts, marker="x", linewidth=1)
            ax2.set_ylabel(r'$\frac{p_T}{p_T[w]}$',fontsize=25)
            # ax2.set_ylim((0.97,1.3))
            ax2.set_yticklabels([0.97, 1.0, 1.3])

# %%
pt_w_cut_ratio(file_pre, file_post, N=100000)
# Out:
# file keys [b'tree;1']
#
# treepre keys [b'numJets', b'pTJet', b'evtWeight']
# treepost keys [b'numJets', b'pTJet', b'evtWeight']
#
# treepre["pTJet"] = <TBranch b'pTJet' at 0x7f55464876d0>
# ptpre= [  0.           0.         285.03810387 192.98279924 128.00686358
#   42.86144494  34.67190142  25.53549635  19.48882637  16.81313874]
# ptpost= [  0.           0.          28.87643675  26.9488977   12.71211775
#   12.71211775  12.71211775 375.07528705 372.64908738  61.90323897]
#
#  parton_jet_pT_min, parton_jet_pT_max = 	  0.0 ,	 3604.7934847998154
#
# parton_jet_pT_shape =  (300000,)
#
#  evweight_pre_min, evweight_pre_max = 	  1.8273135085853847e-11 ,	 0.998180472645993
#
# evweight_pre_shape =  (300000,)
#
#  parton_jet_event_weights_min, parton_jet_event_weights_max = 	  1.8273135085853847e-11 ,	 0.998180472645993
#
# parton_jet_event_weights_shape =  (300000,)
# slope=-4.5
# /home/ali/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: RuntimeWarning: divide by zero encountered in log
# /home/ali/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:63: RuntimeWarning: invalid value encountered in true_divide
# /home/ali/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:66: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# $$bias=\left(\frac{\hat{p}_T}{p_{T,ref}}\right)^{pow}$$
# with $pow=PhaseSpace:bias2SelectionPow$ . Then events are basically assigned a compensating weight (which undersamples an event) which is the inverse of the bias
# $$Event.weight()= \frac{1}{\left(\frac{\hat{p}_T}{p_{T,ref}}\right)^{pow}}$$

# %% [markdown]
# $$\log(w) = - pow \log\left(\frac{\hat{p_T}}{p_{T,ref}}\right)  $$

# %% [markdown]
# $$\log(w) = - pow \left[ \log(\hat{p}_T) - \log(p_{T,ref}) \right]$$

# %% [markdown]
# PhaseSpace:bias2SelectionPow = 4.5
#
# PhaseSpace:bias2SelectionRef = 15.

# %%
np.log(15)*4.5
# Out:
# 12.186225904959946

# %% [markdown]
# $$\log(w) = -4.5 \log(\hat{p}_T) + 12.186 $$

# %%
import pandas as pd
def plt_weights_two_files(filepre, filepost, N):
    with uproot.open(filepre) as filepre:
        with uproot.open(filepost) as filepost:
            print('file keys', filepre.keys())
            treepre = filepre["tree"]
            treepost = filepost["tree"]
            print()
            print('treepre keys',treepre.keys())
            print('treepost keys',treepost.keys())
            print()
            print('treepre["pTJet"] =',treepre["pTJet"])
    #         print()
    
            Axes_font=25
            ptpre = treepre.arrays(["pTJet"], outputtype = tuple)[0].flatten()            
            ptpost = treepost.arrays(["pTJet"], outputtype = tuple)[0].flatten()
            print('ptpre=', ptpre[:10])
            print('ptpost=', ptpost[:10])
            show_basic_info(ptpre, label='parton_jet_pT')
            
            evweight_pre = treepre.arrays('evtWeight', outputtype=tuple)[0].flatten()
            evweight_post = treepost.arrays('evtWeight', outputtype=tuple)[0].flatten()
            # evweight_pre = 1/evweight_pre
            # evweight_post = 1/evweight_post
            
            # evweight_pre, evweight_post = 1/evweight_pre, 1/evweight_post
            show_basic_info(evweight_pre, label='parton_jet_event_weights')
            # show_basic_info(evweight_post, label='hadron_jet_event_weights')
            # df = pd.DataFrame({'pt_PS':ptpre, 'pt_PS_MPI+HAD':ptpost, 'w_PS':evweight_pre,  'w_PS_MPI_HAD':evweight_post})
            # df.to_csv('Jetweight_and_pT.csv')

#             fig, ax = plt.subplots(1,2)
#             if 'pre' in Weight_file: parton_or_hadron = 'parton'
#             else: parton_or_hadron = 'hadron'
#             ax[0].hist(evweight_pre, label='%s jets' % parton_or_hadron,bins=bins)
#             ax[0].set_title(r'CUEP8M1 $N_{events}$ = %s' % str(N))
#             ax[0].set_xlabel(r'$w_{event}$')
#             # ax[0].set_xlim(0,0.5)
#             ax[0].legend()

#             ax[1].hist(pTJet, label='%s jets $p_T$' % parton_or_hadron,bins=bins)
#             ax[1].set_title('CUEP8M1')
#             ax[1].set_xlabel(r'jet $p_T$')
#             ax[1].legend()      
            n_list = [0, 0.5]
            nrows,ncols = len(n_list)+1, 2
            fig, ax = plt.subplots(nrows,ncols, figsize=(20,15))
            hist_ax(ax=ax[0,0], values=evweight_pre, label='PS jet', xlabel='event weight', alpha=0.35, 
                    yscale='log',
                    xscale='log',
                    bins=100)
            hist_ax(ax=ax[0,0], values=evweight_post, label='PS+MPI+HAD jet', xlabel='event weight', alpha=0.35, 
                    yscale='log',
                    xscale='log',
                    bins=100)
            weight_pre_median = np.median(evweight_pre)
            print(f'weight_pre_median={weight_pre_median}')
            # Anotate median
            ax[0,0].axvline(x=weight_pre_median, label = 'pre w median', linestyle="--", color='red')
            weight_post_median = np.median(evweight_post)
            ax[0,0].axvline(x=weight_post_median, label = 'post w median', linestyle="-", color='black')
            ax[0,0].text(0.1,0.6, r'$med(w_{PS}) \approx med(w_{PS+MPI+HAD})$', transform=ax[0,0].transAxes, color='blue', fontsize=Axes_font)
            # plot pT
            ax[0,1].hist(ptpre, label='PS jet', alpha=0.35, 
                    # xscale='log',
                    bins=100)
            hist_ax(ax=ax[0,1], values=ptpost, label='PS+MPI+HAD jet', xlabel=r'Jet $p_T$ [GeV]', alpha=0.35, 
                    # yscale='log',
                    # xscale='log',
                    bins=100)
            ax[0,1].text(0.1,0.6, 'no weight cut', transform=ax[0,1].transAxes, color='blue',fontsize=Axes_font)
            evweight_pre=np.array(evweight_pre)
            w_pre_range= evweight_pre.min(), evweight_pre.max()
            std_w_pre = np.std(evweight_pre)
            std_w_post = np.std(evweight_post)
            print(f'std_w_pre={std_w_pre}')
            
            ################################### Loop over n list
            
            # w_thresh = med(w) + n * sigma
            for n_i, n in enumerate(n_list):
                w_thresh_pre = weight_pre_median + n * std_w_pre
                #note that we cannot do weight_pre_median - n * std_w_pre, because sigma > median(w)
                print(f'w_thresh_pre={w_thresh_pre}')
                w_thresh_post = weight_post_median + n * std_w_post
                ax[n_i + 1, 0].axvline(x=w_thresh_pre, linestyle="--", color='red',alpha=0.5)#red for pre
                ax[n_i + 1, 0].axvline(x=w_thresh_post, linestyle="-", color='black',alpha=0.5)#black for post

                #we since the weights go from 0 to 1, we want to cut events with weights below the 
                # threshold - that is - we want the mask to be true if an event weight is above w_thresh
                #The Thresholds are the masks
                w_thresh_pre = evweight_pre > w_thresh_pre
                w_thresh_post = evweight_post > w_thresh_post
                selected_w_pre = evweight_pre[w_thresh_pre]
                selected_w_post = evweight_post[w_thresh_post]
                selected_pt_pre = ptpre[w_thresh_pre]
                selected_pt_post = ptpost[w_thresh_post]
                #####fill weight hists for different w_thresh
                ax[n_i + 1, 0].hist(evweight_pre, label='PS jet', alpha=0.35, 
                    bins=100,
                range=w_pre_range)
                ax[n_i + 1, 0].hist(evweight_post, label='PS+MPI+HAD jet', alpha=0.35, 
                    bins=100,
                range=w_pre_range)
                
                ##### Fill pT distributions subject to different w_thresh
                ax[n_i + 1, 1].hist(selected_pt_pre, label='PS jet', alpha=0.35, 
                    bins=100,
                # range=w_pre_range
                                   )
                ax[n_i + 1, 1].hist(selected_pt_post, label='PS+MPI+HAD jet', alpha=0.35, 
                    bins=100,
                # range=w_pre_range
                                   )
                print(f'ptpost.shape={ptpost.shape}, selected_w_post.shape={selected_w_post.shape}, w_thresh_pre={w_thresh_pre}')
                #text at the end
                ax[n_i + 1, 0].text(0.35,0.6, s=r'$w_{thresh}^{PS}=med(w_{PS}) + %s \sigma(w_{PS})$' % str(n), transform=ax[n_i + 1,0].transAxes, color='red',fontsize=Axes_font-5)
                ax[n_i + 1, 0].text(0.35,0.4, s=r'$w_{thresh}^{PS+MPI+HAD}=med(w_{PS+MPI+HAD}) + %s \sigma(w_{PS+MPI+HAD})$' % str(n), transform=ax[n_i + 1,0].transAxes, color='black',fontsize=Axes_font-5)
                
            for i in range(nrows):
                for j in range(ncols):
                    #in both columns y axis is log
                    ax[i,j].set_ylabel('log(Counts)' ,fontsize=Axes_font)
                    ax[i,j].set_yscale('log')
                    # also, set the x scale to log for weights
                    ax[i,0].set_xscale('log')
                    ax[i,0].set_xlabel(r'$log w_{event}$',fontsize=Axes_font)
                    ax[i,1].set_xlabel(r'Jet $p_T$ [GeV]',fontsize=Axes_font)
                    
                    ax[i,j].legend(loc='upper right',fontsize=15)
            fig.suptitle(r'Py8 CUETP8M1 with bias, $N_{events}$ = %sK' % str(int(N/1000)), fontsize=22)
            
            # plt.tight_layout(); 
            fig.subplots_adjust(top=0.8)
            fig.tight_layout()
            plt.savefig('median_w_cut_doesnt_work.png')
            plt.show()
            #in uproot the np array that you want is the 0the element of the tuple
            return evweight_pre, evweight_post, ptpre, ptpost

# %%
file_pre='biased/pre/WEIGHTS_pre_100K_ParisParams_biased.root'
file_post='biased/post/WEIGHTS_post_100K_ParisParams_biased.root'

evweight_pre, evweight_post, ptpre, ptpost = plt_weights_two_files(file_pre, file_post, N=100000)
# Out:
# file keys [b'tree;1']
#
# treepre keys [b'numJets', b'pTJet', b'evtWeight']
# treepost keys [b'numJets', b'pTJet', b'evtWeight']
#
# treepre["pTJet"] = <TBranch b'pTJet' at 0x7fcfe0cc9fd0>
# ptpre= [  0.           0.         285.03810387 192.98279924 128.00686358
#   42.86144494  34.67190142  25.53549635  19.48882637  16.81313874]
# ptpost= [  0.           0.          28.87643675  26.9488977   12.71211775
#   12.71211775  12.71211775 375.07528705 372.64908738  61.90323897]
#
#  parton_jet_pT_min, parton_jet_pT_max = 	  0.0 ,	 3821.879067850399
#
# parton_jet_pT_shape =  (691969,)
#
#  parton_jet_event_weights_min, parton_jet_event_weights_max = 	  1.8273135085853847e-11 ,	 0.998180472645993
#
# parton_jet_event_weights_shape =  (691969,)
# weight_pre_median=6.693573649029677e-06
# std_w_pre=0.06652259465033701
# w_thresh_pre=6.693573649029677e-06
# ptpost.shape=(713189,), selected_w_post.shape=(356592,), w_thresh_pre=[False False False ...  True  True  True]
# w_thresh_pre=0.03326799089881754
# ptpost.shape=(713189,), selected_w_post.shape=(35279,), w_thresh_pre=[False False False ... False False False]

# %%
def plt_weights_two_files_unbiased(filepre_nobias, filepost_nobias, filepre_withbias, filepost_withbias, N):
        with uproot.open(filepre_nobias) as filepre_nobias, uproot.open(filepost_nobias) as filepost_nobias, uproot.open(filepre_withbias) as filepre_withbias, uproot.open(filepost_withbias) as filepost_withbias:
            print('file keys', filepre_nobias.keys())
            treepre_nobias = filepre_nobias["tree"]
            treepost_nobias = filepost_nobias["tree"]
            
            
            treepre_withbias = filepre_withbias["tree"]
            treepost_withbias = filepost_withbias["tree"]
            print()
            print('treepre keys',treepre_nobias.keys())
            print('treepost keys',treepost_nobias.keys())
            print()
            print('treepre["pTJet"] =',treepre_nobias["pTJet"])
    #         print()

            #no bias
            ptpre_nobias = treepre_nobias.arrays(["pTJet"], outputtype = tuple)
            ptpost_nobias = treepost_nobias.arrays(["pTJet"], outputtype = tuple)
            show_basic_info(ptpre_nobias, label='parton_jet_pT_no_bias')

            evweight_pre_nobias = treepre_nobias.arrays('evtWeight', outputtype=tuple)
            evweight_post_nobias = treepost_nobias.arrays('evtWeight', outputtype=tuple) 
            show_basic_info(evweight_pre_nobias, label='parton_jet_event_weights_nobias')
            show_basic_info(evweight_post_nobias, label='hadron_jet_event_weights_nobias')

            #with bias
            ptpre_withbias = treepre_withbias.arrays(["pTJet"], outputtype = tuple)
            ptpost_withbias = treepost_withbias.arrays(["pTJet"], outputtype = tuple)
            show_basic_info(ptpre_withbias, label='parton_jet_pT_withbias')

            evweight_pre_withbias = treepre_withbias.arrays('evtWeight', outputtype=tuple)
            evweight_post_withbias = treepost_withbias.arrays('evtWeight', outputtype=tuple) 
            show_basic_info(evweight_pre_withbias, label='parton_jet_event_weights_withbias')
            show_basic_info(evweight_post_withbias, label='hadron_jet_event_weights_withbias')
            
            fig_height=10; fig_width=fig_height*1.33
            fig, ax = plt.subplots(2,2,figsize=(fig_width,fig_height))
            #no bias
            hist_ax(ax=ax[0,0], values=evweight_pre_nobias, label='parton jet', xlabel='event weight', alpha=0.35, yscale='log', ax_title='No bias, $N_{events}$ = %s K' % str(int(N/1000))) 
            hist_ax(ax=ax[0,0], values=evweight_post_nobias, label='hadron jet', xlabel='event weight', alpha=0.35, yscale='log',  ax_title='No bias, $N_{events}$ = %s K' % str(int(N/1000))) 

            hist_ax(ax=ax[0,1], values=ptpre_nobias, label='parton jet', xlabel=r'Jet $p_T$ [GeV]', alpha=0.35, yscale='log', ax_title='No bias, $N_{events}$ = %s K' % str(int(N/1000)))
            hist_ax(ax=ax[0,1], values=ptpost_nobias, label='hadron jet', xlabel=r'Jet $p_T$ [GeV]', alpha=0.35, yscale='log', ax_title='No bias, $N_{events}$ = %s K' % str(int(N/1000)))
            #with bias
            hist_ax(ax=ax[1,0], values=evweight_pre_withbias, label='parton jet', xlabel='event weight', alpha=0.35, yscale='log', ax_title='With bias, $N_{events}$ = %s K' % str(int(N/1000))) 
            hist_ax(ax=ax[1,0], values=evweight_post_withbias, label='hadron jet', xlabel='event weight', alpha=0.35, yscale='log',  ax_title='With bias, $N_{events}$ = %s K' % str(int(N/1000))) 

            hist_ax(ax=ax[1,1], values=ptpre_withbias, label='parton jet', xlabel=r'Jet $p_T$ [GeV]', alpha=0.35, yscale='log', ax_title='With bias, $N_{events}$ = %s K' % str(int(N/1000)))
            hist_ax(ax=ax[1,1], values=ptpost_withbias, label='hadron jet', xlabel=r'Jet $p_T$ [GeV]', alpha=0.35, yscale='log', ax_title='With bias, $N_{events}$ = %s K' % str(int(N/1000)))
            
            fig.suptitle(r'Pythia8; CUETP8M1',fontsize=26)
            plt.tight_layout(); 
            # plt.savefig('images/bias_nobias_weight_pt.png')
            plt.show()

# %%
#signature: filepre_nobias, filepost_nobias, filepre_withbias, filepost_withbias
file_pre_biased='biased/pre/WEIGHTS_pre_10K_ParisParams.root'
file_post_biased='biased/post/WEIGHTS_post_10K_ParisParams.root'

file_pre='biased/pre/WEIGHTS_pre_100K_ParisParams_biased.root'
file_post='biased/post/WEIGHTS_post_100K_ParisParams_biased.root'

plt_weights_two_files_unbiased(filepre_nobias='unbiased/WEIGHTS_pre_100K_ParisParams_unbiased.root', 
                               filepost_nobias='unbiased/WEIGHTS_post_100K_ParisParams_unbiased.root', 
                    filepre_withbias=file_pre, filepost_withbias=file_post, N=100000)
# Out:
# file keys [b'tree;1']
#
# treepre keys [b'numJets', b'pTJet', b'evtWeight']
# treepost keys [b'numJets', b'pTJet', b'evtWeight']
#
# treepre["pTJet"] = <TBranch b'pTJet' at 0x7f2100c73b10>
#
#  parton_jet_pT_no_bias_min, parton_jet_pT_no_bias_max = 	  0.0 ,	 371.03135458975487
#
# parton_jet_pT_no_bias_shape =  (1, 376243)
#
#  parton_jet_event_weights_nobias_min, parton_jet_event_weights_nobias_max = 	  1.0 ,	 1.0
#
# parton_jet_event_weights_nobias_shape =  (1, 376243)
#
#  hadron_jet_event_weights_nobias_min, hadron_jet_event_weights_nobias_max = 	  1.0 ,	 1.0
#
# hadron_jet_event_weights_nobias_shape =  (1, 403949)
#
#  parton_jet_pT_withbias_min, parton_jet_pT_withbias_max = 	  0.0 ,	 3821.879067850399
#
# parton_jet_pT_withbias_shape =  (1, 691969)
#
#  parton_jet_event_weights_withbias_min, parton_jet_event_weights_withbias_max = 	  1.8273135085853847e-11 ,	 0.998180472645993
#
# parton_jet_event_weights_withbias_shape =  (1, 691969)
#
#  hadron_jet_event_weights_withbias_min, hadron_jet_event_weights_withbias_max = 	  1.1558228896103506e-11 ,	 0.9987902021413559
#
# hadron_jet_event_weights_withbias_shape =  (1, 713189)

# %%
#signature: filepre_nobias, filepost_nobias, filepre_withbias, filepost_withbias
filepre_nobias='unbiased/pre/WEIGHTS_pre_1K_ParisParams_unbiased.root'
filepost_nobias='unbiased/post/WEIGHTS_post_1K_ParisParams_unbiased.root'


file_pre_biased='biased/pre/WEIGHTS_pre_1K_ParisParams_biased.root'
file_post_biased='biased/post/WEIGHTS_post_1K_ParisParams_biased.root'

plt_weights_two_files_unbiased(filepre_nobias=filepre_nobias, 
                               filepost_nobias=filepost_nobias, 
                    filepre_withbias=file_pre_biased, 
                               filepost_withbias=file_post_biased, 
                               N=1000)
# Out:
# file keys [b'tree;1']
#
# treepre keys [b'numJets', b'pTJet', b'evtWeight']
# treepost keys [b'numJets', b'pTJet', b'evtWeight']
#
# treepre["pTJet"] = <TBranch b'pTJet' at 0x7fbf9f854c10>
#
#  parton_jet_pT_no_bias_min, parton_jet_pT_no_bias_max = 	  0.0 ,	 137.1637607862249
#
# parton_jet_pT_no_bias_shape =  (1, 3786)
#
#  parton_jet_event_weights_nobias_min, parton_jet_event_weights_nobias_max = 	  1.0 ,	 1.0
#
# parton_jet_event_weights_nobias_shape =  (1, 3786)
#
#  hadron_jet_event_weights_nobias_min, hadron_jet_event_weights_nobias_max = 	  1.0 ,	 1.0
#
# hadron_jet_event_weights_nobias_shape =  (1, 4012)
#
#  parton_jet_pT_withbias_min, parton_jet_pT_withbias_max = 	  0.0 ,	 2277.7765768883205
#
# parton_jet_pT_withbias_shape =  (1, 6965)
#
#  parton_jet_event_weights_withbias_min, parton_jet_event_weights_withbias_max = 	  2.0054732472197606e-10 ,	 0.9280654550400511
#
# parton_jet_event_weights_withbias_shape =  (1, 6965)
#
#  hadron_jet_event_weights_withbias_min, hadron_jet_event_weights_withbias_max = 	  2.5271318218963586e-11 ,	 0.8308264869890059
#
# hadron_jet_event_weights_withbias_shape =  (1, 7188)

# %%
def plt_2d_hist_two_files_unbiased(filepre_nobias, filepost_nobias, filepre_withbias, filepost_withbias, N):
        with uproot.open(filepre_nobias) as filepre_nobias, uproot.open(filepost_nobias) as filepost_nobias, uproot.open(filepre_withbias) as filepre_withbias, uproot.open(filepost_withbias) as filepost_withbias:
            print('file keys', filepre_nobias.keys())
            treepre_nobias = filepre_nobias["tree"]
            treepost_nobias = filepost_nobias["tree"]
            
            treepre_withbias = filepre_withbias["tree"]
            treepost_withbias = filepost_withbias["tree"]
            print()
            print('treepre keys',treepre_nobias.keys())
            print('treepost keys',treepost_nobias.keys())
            print()
            print('treepre["pTJet"] =',treepre_nobias["pTJet"])
    #         print()

            #no bias
            ptpre_nobias = treepre_nobias.arrays(["pTJet"], outputtype = tuple)
            ptpost_nobias = treepost_nobias.arrays(["pTJet"],outputtype = tuple)
            show_basic_info(ptpre_nobias, label='parton_jet_pT_no_bias')

            evweight_pre_nobias = treepre_nobias.arrays('evtWeight', outputtype=tuple)
            evweight_post_nobias = treepost_nobias.arrays('evtWeight', outputtype=tuple) 
            show_basic_info(evweight_pre_nobias, label='parton_jet_event_weights_nobias')
            show_basic_info(evweight_post_nobias, label='hadron_jet_event_weights_nobias')

            #with bias
            ptpre_withbias = treepre_withbias.arrays(["pTJet"], outputtype = tuple)
            ptpost_withbias = treepost_withbias.arrays(["pTJet"], outputtype = tuple)
            show_basic_info(ptpre_withbias, label='parton_jet_pT_withbias')

            evweight_pre_withbias = treepre_withbias.arrays('evtWeight', outputtype=tuple)
            evweight_post_withbias = treepost_withbias.arrays('evtWeight', outputtype=tuple) 
            show_basic_info(evweight_pre_withbias, label='parton_jet_event_weights_withbias')
            show_basic_info(evweight_post_withbias, label='hadron_jet_event_weights_withbias')
            
            fig_height=10; fig_width=fig_height*1.33
            fig, ax = plt.subplots(1,2,figsize=(fig_width,fig_height))
            #no bias hadron jet
            # X_nobias = np.array(evweight_pre_nobias).flatten()#weight
            W_nobias_post=np.array(evweight_post_nobias).flatten()
            PT_nobias_post = np.array(ptpost_nobias).flatten() #pt jet
            
#             H_2d, W_edges, pT_edges = np.histogram2d(W_nobias_post,PT_nobias_post, bins=(16,16) ) 
            
#             W_nobias_post=get_centers(W_edges)
#             PT_nobias_post = get_centers(pT_edges)
            
#             WEIGHT_nobias, PT_nobias = np.meshgrid(W_nobias_post,PT_nobias_post)
#             WEIGHT_nobias=WEIGHT_nobias.flatten()
#             PT_nobias=PT_nobias.flatten()
            
            # ax[0].hist2d(WEIGHT_nobias, PT_nobias, bins=(16,16), cmap='gist_earth_r')
            ax[0].hist2d(W_nobias_post, PT_nobias_post, cmap=plt.cm.jet)
            ax[0].set_xlabel('weight')
            ax[0].set_ylabel(r'$p_T^{hadron jet}$')
            ax[0].grid()
            ax[0].set_title('no bias')
            
            
            
            
            
            
            
            
            
            
            
            
            
            
            
            
            
            ############################################################################################
            W_withbias_post=np.array(evweight_post_withbias).flatten()
            PT_withbias_post = np.array(ptpost_withbias).flatten() #pt jet
            
            # H_2d, W_edges, pT_edges = np.histogram2d(W_withbias_post,PT_withbias_post, bins=(16,16) ) 
            
#             W_withbias_post=get_centers(W_edges)
#             PT_withbias_post = get_centers(pT_edges)
            
#             WEIGHT_WITHBIAS, PT_WITHBIAS = np.meshgrid(W_withbias_post,PT_withbias_post)
#             WEIGHT_WITHBIAS=WEIGHT_WITHBIAS.flatten()
#             PT_WITHBIAS=PT_WITHBIAS.flatten()
                
            # ax[1].hist2d(WEIGHT_WITHBIAS, PT_WITHBIAS, bins=(16,16), cmap='gist_earth_r')
            ax[1].hist2d(W_withbias_post, PT_withbias_post, cmap=plt.cm.jet)
            ax[1].set_xlabel('weight')
            ax[1].set_ylabel(r'$p_T^{hadron jet}$')
            ax[1].grid()
            ax[0].set_title('with bias')
            
            
            
#             hist_ax(ax=ax[0,0], values=evweight_pre_nobias, label='parton jet', xlabel='event weight', alpha=0.35, yscale='log', ax_title='No bias, $N_{events}$ = %s K' % str(int(N/1000))) 
#             hist_ax(ax=ax[0,0], values=evweight_post_nobias, label='hadron jet', xlabel='event weight', alpha=0.35, yscale='log',  ax_title='No bias, $N_{events}$ = %s K' % str(int(N/1000))) 

#             hist_ax(ax=ax[0,1], values=ptpre_nobias, label='parton jet', xlabel=r'Jet $p_T$ [GeV]', alpha=0.35, yscale='log', ax_title='No bias, $N_{events}$ = %s K' % str(int(N/1000)))
#             hist_ax(ax=ax[0,1], values=ptpost_nobias, label='hadron jet', xlabel=r'Jet $p_T$ [GeV]', alpha=0.35, yscale='log', ax_title='No bias, $N_{events}$ = %s K' % str(int(N/1000)))
#             #with bias
#             hist_ax(ax=ax[1,0], values=evweight_pre_withbias, label='parton jet', xlabel='event weight', alpha=0.35, yscale='log', ax_title='With bias, $N_{events}$ = %s K' % str(int(N/1000))) 
#             hist_ax(ax=ax[1,0], values=evweight_post_withbias, label='hadron jet', xlabel='event weight', alpha=0.35, yscale='log',  ax_title='With bias, $N_{events}$ = %s K' % str(int(N/1000))) 

#             hist_ax(ax=ax[1,1], values=ptpre_withbias, label='parton jet', xlabel=r'Jet $p_T$ [GeV]', alpha=0.35, yscale='log', ax_title='With bias, $N_{events}$ = %s K' % str(int(N/1000)))
#             hist_ax(ax=ax[1,1], values=ptpost_withbias, label='hadron jet', xlabel=r'Jet $p_T$ [GeV]', alpha=0.35, yscale='log', ax_title='With bias, $N_{events}$ = %s K' % str(int(N/1000)))
            
            # fig.suptitle(r'Pythia8; CUETP8M1',fontsize=26)
            plt.tight_layout(); plt.show()

# %%
#signature: filepre_nobias, filepost_nobias, filepre_withbias, filepost_withbias
filepre_nobias='unbiased/pre/WEIGHTS_pre_1K_ParisParams_unbiased.root'
filepost_nobias='unbiased/post/WEIGHTS_post_1K_ParisParams_unbiased.root'


file_pre_biased='biased/pre/WEIGHTS_pre_1K_ParisParams_biased.root'
file_post_biased='biased/post/WEIGHTS_post_1K_ParisParams_biased.root'

plt_2d_hist_two_files_unbiased(filepre_nobias=filepre_nobias, 
                               filepost_nobias=filepost_nobias, 
                    filepre_withbias=file_pre_biased, 
                               filepost_withbias=file_post_biased, 
                               N=100000)
# Out:
# file keys [b'tree;1']
#
# treepre keys [b'numJets', b'pTJet', b'evtWeight']
# treepost keys [b'numJets', b'pTJet', b'evtWeight']
#
# treepre["pTJet"] = <TBranch b'pTJet' at 0x7fbfa428d910>
#
#  parton_jet_pT_no_bias_min, parton_jet_pT_no_bias_max = 	  0.0 ,	 137.1637607862249
#
# parton_jet_pT_no_bias_shape =  (1, 3786)
#
#  parton_jet_event_weights_nobias_min, parton_jet_event_weights_nobias_max = 	  1.0 ,	 1.0
#
# parton_jet_event_weights_nobias_shape =  (1, 3786)
#
#  hadron_jet_event_weights_nobias_min, hadron_jet_event_weights_nobias_max = 	  1.0 ,	 1.0
#
# hadron_jet_event_weights_nobias_shape =  (1, 4012)
#
#  parton_jet_pT_withbias_min, parton_jet_pT_withbias_max = 	  0.0 ,	 2277.7765768883205
#
# parton_jet_pT_withbias_shape =  (1, 6965)
#
#  parton_jet_event_weights_withbias_min, parton_jet_event_weights_withbias_max = 	  2.0054732472197606e-10 ,	 0.9280654550400511
#
# parton_jet_event_weights_withbias_shape =  (1, 6965)
#
#  hadron_jet_event_weights_withbias_min, hadron_jet_event_weights_withbias_max = 	  2.5271318218963586e-11 ,	 0.8308264869890059
#
# hadron_jet_event_weights_withbias_shape =  (1, 7188)

# %%
def transfer_matrix(filepre_nobias, filepost_nobias, filepre_withbias, filepost_withbias, N):
        with uproot.open(filepre_nobias) as filepre_nobias, uproot.open(filepost_nobias) as filepost_nobias, uproot.open(filepre_withbias) as filepre_withbias, uproot.open(filepost_withbias) as filepost_withbias:
            print('file keys', filepre_nobias.keys())
            treepre_nobias = filepre_nobias["tree"]
            treepost_nobias = filepost_nobias["tree"]
            
            treepre_withbias = filepre_withbias["tree"]
            treepost_withbias = filepost_withbias["tree"]
            print()
            print('treepre keys',treepre_nobias.keys())
            print('treepost keys',treepost_nobias.keys())
            print()
            print('treepre["pTJet"] =',treepre_nobias["pTJet"])
    #         print()

            #no bias
            ptpre_nobias = treepre_nobias.arrays(["pTJet"], outputtype = tuple)
            ptpost_nobias = treepost_nobias.arrays(["pTJet"],outputtype = tuple)
            show_basic_info(ptpre_nobias, label='parton_jet_pT_no_bias')

            evweight_pre_nobias = treepre_nobias.arrays('evtWeight', outputtype=tuple)
            evweight_post_nobias = treepost_nobias.arrays('evtWeight', outputtype=tuple) 
            show_basic_info(evweight_pre_nobias, label='parton_jet_event_weights_nobias')
            show_basic_info(evweight_post_nobias, label='hadron_jet_event_weights_nobias')

            #with bias
            ptpre_withbias = treepre_withbias.arrays(["pTJet"], outputtype = tuple)
            ptpost_withbias = treepost_withbias.arrays(["pTJet"], outputtype = tuple)
            show_basic_info(ptpre_withbias, label='parton_jet_pT_withbias')

            evweight_pre_withbias = treepre_withbias.arrays('evtWeight', outputtype=tuple)
            evweight_post_withbias = treepost_withbias.arrays('evtWeight', outputtype=tuple) 
            show_basic_info(evweight_pre_withbias, label='parton_jet_event_weights_withbias')
            show_basic_info(evweight_post_withbias, label='hadron_jet_event_weights_withbias')
            
            fig_height=10; fig_width=fig_height*1.33
            fig, ax = plt.subplots(1,1,figsize=(fig_width,fig_height))
            #no bias hadron jet
            # X_nobias = np.array(evweight_pre_nobias).flatten()#weight
            W_nobias_post=np.array(evweight_post_nobias).flatten()
            PT_nobias_post = np.array(ptpost_nobias).flatten() #pt jet
            
#             H_2d, W_edges, pT_edges = np.histogram2d(W_nobias_post,PT_nobias_post, bins=(16,16) ) 
            
#             W_nobias_post=get_centers(W_edges)
#             PT_nobias_post = get_centers(pT_edges)
            
#             WEIGHT_nobias, PT_nobias = np.meshgrid(W_nobias_post,PT_nobias_post)
#             WEIGHT_nobias=WEIGHT_nobias.flatten()
#             PT_nobias=PT_nobias.flatten()
            
            # ax[0].hist2d(WEIGHT_nobias, PT_nobias, bins=(16,16), cmap='gist_earth_r')
       
            
            
            
            
            
            
            
            
            
            
            
            
            
            
            
            
            
            ############################################################################################
            W_withbias_post=np.array(evweight_post_withbias).flatten()
            PT_withbias_post = np.array(ptpost_withbias).flatten() #pt jet
            PT_withbias_pre = np.array(ptpre_withbias).flatten() #pt jet
            PT_withbias_post=PT_withbias_post[:len(PT_withbias_pre)]
            # H_2d, W_edges, pT_edges = np.histogram2d(W_withbias_post,PT_withbias_post, bins=(16,16) ) 
            
#             W_withbias_post=get_centers(W_edges)
#             PT_withbias_post = get_centers(pT_edges)
            
#             WEIGHT_WITHBIAS, PT_WITHBIAS = np.meshgrid(W_withbias_post,PT_withbias_post)
#             WEIGHT_WITHBIAS=WEIGHT_WITHBIAS.flatten()
#             PT_WITHBIAS=PT_WITHBIAS.flatten()
                
            # ax[1].hist2d(WEIGHT_WITHBIAS, PT_WITHBIAS, bins=(16,16), cmap='gist_earth_r')
            ax.hist2d(PT_withbias_pre, PT_withbias_post, bins=(4,4), cmap=plt.cm.jet)
            ax.set_xlabel(r'$p_T$ PS')
            ax.set_ylabel(r'$p_T$ PS+MPI+HAD' )
            ax.grid()
            ax.set_title('with bias')
            
            
            
#             hist_ax(ax=ax[0,0], values=evweight_pre_nobias, label='parton jet', xlabel='event weight', alpha=0.35, yscale='log', ax_title='No bias, $N_{events}$ = %s K' % str(int(N/1000))) 
#             hist_ax(ax=ax[0,0], values=evweight_post_nobias, label='hadron jet', xlabel='event weight', alpha=0.35, yscale='log',  ax_title='No bias, $N_{events}$ = %s K' % str(int(N/1000))) 

#             hist_ax(ax=ax[0,1], values=ptpre_nobias, label='parton jet', xlabel=r'Jet $p_T$ [GeV]', alpha=0.35, yscale='log', ax_title='No bias, $N_{events}$ = %s K' % str(int(N/1000)))
#             hist_ax(ax=ax[0,1], values=ptpost_nobias, label='hadron jet', xlabel=r'Jet $p_T$ [GeV]', alpha=0.35, yscale='log', ax_title='No bias, $N_{events}$ = %s K' % str(int(N/1000)))
#             #with bias
#             hist_ax(ax=ax[1,0], values=evweight_pre_withbias, label='parton jet', xlabel='event weight', alpha=0.35, yscale='log', ax_title='With bias, $N_{events}$ = %s K' % str(int(N/1000))) 
#             hist_ax(ax=ax[1,0], values=evweight_post_withbias, label='hadron jet', xlabel='event weight', alpha=0.35, yscale='log',  ax_title='With bias, $N_{events}$ = %s K' % str(int(N/1000))) 

#             hist_ax(ax=ax[1,1], values=ptpre_withbias, label='parton jet', xlabel=r'Jet $p_T$ [GeV]', alpha=0.35, yscale='log', ax_title='With bias, $N_{events}$ = %s K' % str(int(N/1000)))
#             hist_ax(ax=ax[1,1], values=ptpost_withbias, label='hadron jet', xlabel=r'Jet $p_T$ [GeV]', alpha=0.35, yscale='log', ax_title='With bias, $N_{events}$ = %s K' % str(int(N/1000)))
            
            # fig.suptitle(r'Pythia8; CUETP8M1',fontsize=26)
            plt.tight_layout(); plt.show()

# %%
#signature: filepre_nobias, filepost_nobias, filepre_withbias, filepost_withbias
filepre_nobias='unbiased/pre/WEIGHTS_pre_1K_ParisParams_unbiased.root'
filepost_nobias='unbiased/post/WEIGHTS_post_1K_ParisParams_unbiased.root'


file_pre_biased='biased/pre/WEIGHTS_pre_1K_ParisParams_biased.root'
file_post_biased='biased/post/WEIGHTS_post_1K_ParisParams_biased.root'

transfer_matrix(filepre_nobias=filepre_nobias, 
                               filepost_nobias=filepost_nobias, 
                    filepre_withbias=file_pre_biased, 
                               filepost_withbias=file_post_biased, 
                               N=100000)
# Out:
# file keys [b'tree;1']
#
# treepre keys [b'numJets', b'pTJet', b'evtWeight']
# treepost keys [b'numJets', b'pTJet', b'evtWeight']
#
# treepre["pTJet"] = <TBranch b'pTJet' at 0x7fbfa5a88790>
#
#  parton_jet_pT_no_bias_min, parton_jet_pT_no_bias_max = 	  0.0 ,	 137.1637607862249
#
# parton_jet_pT_no_bias_shape =  (1, 3786)
#
#  parton_jet_event_weights_nobias_min, parton_jet_event_weights_nobias_max = 	  1.0 ,	 1.0
#
# parton_jet_event_weights_nobias_shape =  (1, 3786)
#
#  hadron_jet_event_weights_nobias_min, hadron_jet_event_weights_nobias_max = 	  1.0 ,	 1.0
#
# hadron_jet_event_weights_nobias_shape =  (1, 4012)
#
#  parton_jet_pT_withbias_min, parton_jet_pT_withbias_max = 	  0.0 ,	 2277.7765768883205
#
# parton_jet_pT_withbias_shape =  (1, 6965)
#
#  parton_jet_event_weights_withbias_min, parton_jet_event_weights_withbias_max = 	  2.0054732472197606e-10 ,	 0.9280654550400511
#
# parton_jet_event_weights_withbias_shape =  (1, 6965)
#
#  hadron_jet_event_weights_withbias_min, hadron_jet_event_weights_withbias_max = 	  2.5271318218963586e-11 ,	 0.8308264869890059
#
# hadron_jet_event_weights_withbias_shape =  (1, 7188)
